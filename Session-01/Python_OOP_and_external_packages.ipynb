# %% [markdown]
# <a href="https://colab.research.google.com/github/qayyumu/GradioExp/blob/main/Session-01/Python_OOP_and_external_packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Classes & Module 📘
# Python is an object oriented programming language.<br>
# Almost everything in Python is an object, with its properties and methods.<br>
# A Class is like an object constructor, or a "blueprint" for creating objects.<br>

# %% [markdown]
# ### Get list of member functions
#   <code> <b><i>dir(obj)</code></i></b><br>
#   <i><b>dir<i></b> is a python3's bulitin function which iterates over all member functions and prints their names. <br>

# %%
temperature = float(30.55)

# %%
dir(temperature)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
temperature.__add__(10)
# Out:
# 40.55

# %% [markdown]
# # Class & Inheritance
#
# We create classes to organize code, reuse it, and model real-world objects efficiently.
# Inheritance allows a class to reuse and combine features from one or more parent classes.

# %%
class Electronic:
    def __init__(self, brand): # Constructor method to initialize the brand of the electronic device
        self.brand = brand     # Instance variable to store the brand name
    
    def power_on(self):        # Method to simulate powering on the device
        return f"{self.brand} device is now ON."  # Returns a string indicating the device is powered on

# 1. Single Inheritance
class Phone(Electronic):     # Phone class inherits from Electronic class
    def call(self, number):  # Method to simulate making a call
        return f"Calling {number} from my {self.brand}..."  # Returns a string indicating the number being called and the brand of the phone

# 2. Multilevel Inheritance
class SmartPhone(Phone):   # SmartPhone class inherits from Phone class, which in turn inherits from Electronic class
    def browse(self):      # Method to simulate browsing the internet
        return "Opening web browser..."

# 3. Multiple Inheritance
class Camera:     # Camera class does not inherit from any other class
    def take_photo(self):   # Method to simulate taking a photo
        return "Click! Photo saved."

class CameraPhone(SmartPhone, Camera): # CameraPhone class inherits from both SmartPhone and Camera classes, allowing it to use methods from both parent classes
    pass

# Usage
p = CameraPhone("Samsung") # Creating an instance/object of CameraPhone with the brand "Samsung"
print(p.brand) # Accessing the brand attribute from the Electronic class
print(p.power_on()) # From Electronic
print(p.call("911")) # From Phone
print(p.take_photo()) # From Camera
# Out:
# Samsung
# Samsung device is now ON.
# Calling 911 from my Samsung...
# Click! Photo saved.

# %% [markdown]
# ## Files and Directories 📁

# %% [markdown]
# ### Read and write to a file
# If I want to save data permanently, where should I store it? in a file

# %%
def write_to_file(file_name, data):  # Function to write data to a file, takes the file name and data as parameters
    try: #We use try because file operations can fail like invalid file, permission issues, etc.
        with open(file_name, 'w') as file: # Open the file in write mode ('w'),If file exists → overwrite ,If not → create new file
            file.write(data)
    except Exception as e:
        print("unable to read File")
        print(e)

write_to_file('test.txt', 'Cretating a file')

# %%
def read_file_content(file_name):
    try:
        with open(file_name, 'r') as file: # Open the file in read mode ('r'), If file does not exist → FileNotFoundError
            print(file.read())
    except Exception as e:
        print("unable to read File")
        print(e)
read_file_content('test.txt')
# Out:
# Cretating a file

# %%
def write_to_file_improved(file_name, mode, data): # Function to write data to a file with a specified mode (e.g., 'w' for write, 'a' for append)
    try:
        with open(file_name, mode) as file:
            file.write(data)
    except Exception as e:
        print("unable to read File")
        print(e)
write_to_file_improved('test.txt', 'a','\nadded new data')
read_file_content('test.txt')
# Out:
# Cretating a file
# added new data

# %% [markdown]
# ### Iterate over files in directory

# %%
from pathlib import Path # Importing the Path class from the pathlib module, which provides an object-oriented interface for working with file system paths
# p = Path('../') # Create a Path object representing the parent directory (one level up from the current directory)
p = Path() # Create a Path object representing the current directory
print(p.exists()) # Check if the path exists and print the result (True if it exists, False otherwise)
for file in p.glob('*.txt'): 
    print(file)

###################################################
# Challenge: move one directory up in path and    #
# print the content of first .py file             #
# Hint:                                           #
# '.' represent current dir and '../' Parent      #
# to find .py file use p.globe("*.py") and then   #
# print data by using one of above give functions #
###################################################
# Out:
# True
# test.txt

# %% [markdown]
# ## External packages 📤

# %% [markdown]
# ### Numpy
# NumPy stands for Numerical Python.<br>
# NumPy is a Python library used for working with arrays.<br>
# It also has functions for working in domain of linear algebra, fourier transform, and matrices.<br>
#
#     In Python we have lists that serve the purpose of arrays,
#     but they are slow to process.
#     NumPy aims to provide an array object that is up to 50x faster
#     than traditional Python lists.
#     The array object in NumPy is called ndarray, it provides a lot
#     of supporting functions that make working with ndarray very easy.
#     Arrays are very frequently used in data science, where speed and
#     resources are very important.

# %%
import numpy as np

# %% [markdown]
# 1D and 2D Arrays

# %%
x = np.array(100) # Creating a NumPy array with a single element (100) and storing it in variable x
x1 = [100] # Creating a Python list with a single element (100) and storing it in variable x1
y = np.array([100])  # Creating a NumPy array with a single element (100) and storing it in variable y

print(f"x: {x}")
print(f"x1: {x1}")
print(f"y: {y}")

print(f"Array-y, Shape:{y.shape} Dim:{y.ndim}")
print(f"Array, x-type:{type(x)}\n      x1-type:{type(x1)} \n      y-type:{type(y)}")
# Out:
# x: 100
# x1: [100]
# y: [100]
# Array-y, Shape:(1,) Dim:1
# Array, x-type:<class 'numpy.ndarray'>
#       x1-type:<class 'list'>
#       y-type:<class 'numpy.ndarray'>

# %%
y = np.array([100,200])
print(f"Array-y, y:{y}, Shape:{y.shape} Dim:{y.ndim}")

y1 = np.array([[100,200],[300,400]])
print(f"Array-y1, y1:{y1}, Shape:{y1.shape} Dim:{y1.ndim}")

print(f"Array-y1, y1[0][0]:{y1[0][0]}")

## Matrix -- rank 3 tensors
y2 = np.array([ [   [100,200],
                    [300,400] ],
                [   [100,200],
                    [300,400]] ])
print(f"Array-y2, Shape:{y2.shape} Dim,{y2.ndim}")
# Array Slicing
print(f"Array-y2, y2[0][0][1]:{y2[0][0][1]}") #[0] → first layer, [0] → first row, [1] → second column


print("SUM array using numpy:")
print(y1.sum())
print("get array mean using numpy:")
print(y1.mean())
# Out:
# Array-y, y:[100 200], Shape:(2,) Dim:1
# Array-y1, y1:[[100 200]
#  [300 400]], Shape:(2, 2) Dim:2
# Array-y1, y1[0][0]:100
# Array-y2, Shape:(2, 2, 2) Dim,3
# Array-y2, y2[0][0][1]:200
# SUM array using numpy:
# 1000
# get array mean using numpy:
# 250.0

# %% [markdown]
# ## Standard Python (The Slow Way)
# Python has to check the type of every single element, resolve the power function, and store it back, one by one.

# %%
import time

data = list(range(1000000))
start = time.time()

# Explicit for-loop
result = [x*2 for x in data]

print(f"Python Loop time: {time.time() - start:.4f}s")
# Out:
# Python Loop time: 0.1754s

# %% [markdown]
# # NumPy Vectorization (The Fast Way)
# NumPy issues a single instruction to the CPU to process the entire block of memory.

# %%
import numpy as np

data_np = np.arange(1000000)
start = time.time()

# Vectorized operation
result_np = data_np*2

print(f"NumPy time: {time.time() - start:.4f}s")
# Out:
# NumPy time: 0.0109s

# %% [markdown]
# ### Pandas
# Pandas is a Python library used for working with data sets.<br>
# It has functions for analyzing, cleaning, exploring, and manipulating data.<br>
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.<br>
# Usage:<br>
#
#      - Is there a correlation between two or more columns?
#      - What is average value?
#      - Max value?
#      - Min value?

# %% [markdown]
# Import Pandas

# %%
import numpy as np
import pandas as pd
##object creation
s = pd.Series([1,2,3,4,np.nan,6,7]) # Creating a Pandas Series object with a list of values
print(s)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    NaN
# 5    6.0
# 6    7.0
# dtype: float64

# %%
dates = pd.date_range('20220110',periods=5)
print(dates)

# pd.date_range('20220110', periods=5, freq='H')  # hourly
# pd.date_range('20220110', periods=5, freq='M')  # monthly
# Out:
# DatetimeIndex(['2022-01-10', '2022-01-11', '2022-01-12', '2022-01-13',
#                '2022-01-14'],
#               dtype='datetime64[us]', freq='D')

# %%
### dataframe
df = pd.DataFrame(np.random.randn(5,5), index=dates, columns=list('ABCDE'))
# print(df.info())
print(df.head())
# Out:
#                    A         B         C         D         E
# 2022-01-10 -0.967298  1.078089  2.401769 -0.461124  0.524507
# 2022-01-11  0.430193  1.652173  1.259509 -1.124225  1.312569
# 2022-01-12 -0.444182 -0.843601  1.486774  0.281239 -0.242448
# 2022-01-13 -2.699771 -1.022354 -0.111841  0.399166 -0.854918
# 2022-01-14 -0.975525 -0.594319 -0.710437  0.295823  0.321305

# %%
#This code creates a Pandas DataFrame with different types of data in each column.
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220110"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
print(df2.head())
# print(df2.tail(2))
# print(df2.columns)
# Out:
#      A          B    C  D      E    F
# 0  1.0 2022-01-10  1.0  3   test  foo
# 1  1.0 2022-01-10  1.0  3  train  foo
# 2  1.0 2022-01-10  1.0  3   test  foo
# 3  1.0 2022-01-10  1.0  3  train  foo

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2022-01-10  1.0  3   test  foo
# 1  1.0 2022-01-10  1.0  3  train  foo
# 2  1.0 2022-01-10  1.0  3   test  foo
# 3  1.0 2022-01-10  1.0  3  train  foo

# %% [markdown]
# ### Matplot lib
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.<br>
# Matplotlib was created by John D. Hunter.<br>
# Matplotlib is open source and we can use it freely.<br>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from math import sin, cos
xpoints = np.array(range(1,30))
ypoints = []
for i in xpoints:
    ypoints.append(sin(i))
# try using list comprehension
# ypoints = [sin(ypoint) for ypoint in xpoints]
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ### Different types of graphs in Matplotlib
#
# | Plot Type | Matplotlib Function | Best Use Case |
# | :--- | :--- | :--- |
# | **Bar** | `plt.bar()` | Comparing quantities across groups. |
# | **Pie** | `plt.pie()` | Showing proportions/percentage of a total. |
# | **Scatter** | `plt.scatter()` | Finding correlations or clusters in data. |
# | **Line** | `plt.plot()` | Showing trends or mathematical functions. |

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for different types of plots
plot_data = [
    {
        'title': 'Bar Plot',
        'data': {
            'Categories': ['A', 'B', 'C', 'D'],
            'Values': [20, 35, 30, 15]
        }
    },
    {
        'title': 'Pie Chart',
        'data': {
            'Labels': ['Category A', 'Category B', 'Category C'],
            'Sizes': [30, 40, 30],
            'Explode': (0, 0.1, 0)  # Explode second slice (Category B)
        }
    },
    {
        'title': 'Scatter Plot',
        'data': {
            'X': np.random.rand(20),
            'Y': np.random.rand(20) * 100,
            'Sizes': np.random.rand(20) * 100,
            'Colors': np.random.rand(20)
        }
    },
    {
        'title': 'Line Plot',
        'data': {
            'X': np.arange(0, 10, 0.1),
            'Y': np.sin(np.arange(0, 10, 0.1))
        }
    }
]

# Create a 4x4 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 14))

# Flatten axs array for easier indexing
axs = axs.flatten() #This converts the matrix into a simple 1D list. Instead of accessing a plot with axs[0, 1], you can now just use axs[1], which makes looping much easier.

# Iterate through plot_data and plot each type of plot
for i, data in enumerate(plot_data):
    title = data['title']
    plot_data = data['data']

    if title == 'Bar Plot':
        # Bar Plot
        categories = plot_data['Categories']
        values = plot_data['Values']
        axs[i].bar(categories, values, color=['skyblue', 'lightgreen', 'coral', 'gold'])
        axs[i].set_title(title, fontsize=14)

    elif title == 'Pie Chart':
        # Pie Chart
        labels = plot_data['Labels']
        sizes = plot_data['Sizes']
        explode = plot_data['Explode']
        axs[i].pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightskyblue', 'lightgreen'])
        axs[i].set_title(title, fontsize=14)

    elif title == 'Scatter Plot':
        # Scatter Plot
        x = plot_data['X']
        y = plot_data['Y']
        sizes = plot_data['Sizes']
        colors = plot_data['Colors']
        axs[i].scatter(x, y, s=sizes, c=colors, cmap='viridis', alpha=0.8)
        axs[i].set_title(title, fontsize=14)

    elif title == 'Line Plot':
        # Line Plot
        x = plot_data['X']
        y = plot_data['Y']
        axs[i].plot(x, y, color='orange')
        axs[i].set_title(title, fontsize=14)

    axs[i].grid(True)

# Adjust layout and display the grid of plots
plt.tight_layout()
plt.show()

# %% [markdown]
# #### User Connectivity graph

# %%
import matplotlib.pyplot as plt
import networkx as nx  #Python library for studying graphs and networks (like social networks, flight routes, or neural pathways).

# Sample data: Twitter users and their connections (edges)
twitter_users = {
    'User1': ['User2', 'User3', 'User4'],
    'User2': ['User1', 'User3'],
    'User3': ['User1', 'User2', 'User4'],
    'User4': ['User1', 'User3']
}

# Create a directed graph
G = nx.DiGraph()

# Add nodes for each user
for user in twitter_users:
    G.add_node(user)

# Add edges between users based on connections
for user, connections in twitter_users.items():
    for connection in connections:
        G.add_edge(user, connection)

# Draw the graph
pos = nx.spring_layout(G)  # Position nodes using the spring layout algorithm
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=1500, font_size=12, font_color='black', edge_color='gray')

# Display the graph
plt.title('Twitter Users Connectivity Graph')
plt.show()
