# %% [markdown]
# <a href="https://colab.research.google.com/github/qayyumu/GradioExp/blob/main/Session-01/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Intro to Python <table class="tfo-notebook-buttons" align="right" style="margin-top:0px">
#   <td>
#       <a align='left' target="_blank" href="https://www.python.org/doc/"><img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Flogodownload.org%2Fwp-content%2Fuploads%2F2019%2F10%2Fpython-logo.png&f=1&nofb=1&ipt=92ff8f816b6d8c1bd36d772aae08fc560856e3e4adc2fd99a645398e503ccef0&ipo=images"  width="100" /></a>
#   </td>
#  </table>

# %% [markdown]
# ## Data type 🏛
# Python has the following data types built-in by default, in these categories
# ```
#     Text Type     : str
#     Numeric Types : int, float, complex
#     Sequence Types: list, tuple, range
#     Mapping Type  : dict
#     Set Types     : set, frozenset
#     Boolean Type  : bool
#     Binary Types  : bytes, bytearray, memoryview
# ```

# %%
prompt = 'Enter your name:'
message = str('Invalid option')

number = 3
array_index = int(32)

circle_area = 45.356
temperature = float(30.55) 

temperature_float_to_int = int(temperature)
temperature_float_to_string = str(temperature)
print(f"Temperature converted from float to integer: {temperature_float_to_int}")
print(f"Temperature converted from float to string: {temperature_float_to_string}")
# Out:
# Temperature converted from float to integer: 30
# Temperature converted from float to string: 30.55

# %% [markdown]
# ### Get datatype of variable
#   to get data type of a variable pytoh have a built in function named type<br>
#   <code> <b><i>type(obj)</code></i></b><br>
#   obj = object for which data type is to be verified

# %%
print(type(temperature))
# Out:
# <class 'float'>

# %% [markdown]
# ## Conditions and loops

# %% [markdown]
# ### Conditions
#     Equals    : a == b
#     Not Equals: a != b
#     Less than : a < b
#     Greater than: a > b
#     Less than or equal to   : a <= b
#     Greater than or equal to: a >= b
#     and operator: and
#     or operator : or

# %%
a = 1
b = 2
if (a < b):
    print('a is less than b')
    # print(f'{a} is less than {b}')
# else:
#     print(f'{a} is greater than {b}')

#######################################
# exercise 1 uncomment line# 5        #
#######################################

#######################################
# exercise 2 uncomment line# 5~8      #
#######################################
# Out:
# a is less than b

# %% [markdown]
# ## f-string
# ``` let you include values of python expressions inside a string by prefixing the string with f ```

# %%
a = 1
b = 2
if (a < b):
    # print('a is less than b')
    print(f'{a} is less than {b}')
# Out:
# 1 is less than 2

# %%
# if else ladder
a, b, c = (1,2,3)
biggest = -1
if a > b and a > c: #1>2 and 1>3
    biggest = a     #biggest = -1, a = 1
elif b > c:  #2>3
    biggest = b #biggest = 2, b = 2
else:
    biggest = c #biggest = 3, c = 3
print(f'{biggest} is the biggest number')
#######################################################
# exercise Change this code to print smallest Number #
#######################################################
# Out:
# 3 is the biggest number

# %%
# short hand notation
_str = f'{a} is {"greater" if a>b else "less"} than {b}'
print(_str)
# Out:
# 1 is less than 2

# %% [markdown]
# ## Lists and dictionaries 📔

# %% [markdown]
# Lists enable you to store a set of items in place. Lists take the form of arrays in other languages like Java.
#
# A list in Python is created using the following syntax:
# <br><code> listname = [item1, item2, item3, ...]</code>

# %%
aiProblmodelems = ['Classification', 'Regression', 'clustering', 'segmentatoin', 'signalprocessing']
print(aiProblmodelems)
# Out:
# ['Classification', 'Regression', 'clustering', 'segmentatoin', 'signalprocessing']

# %%
array = [1, 2, 3]
emptyArray = []
alsoEmptyArray = list()

length_and_area = (45, 300.456)

# length_and_area.index(45)

# %%
# access list item
Sensor_array = [
    'front_camera',          
    'rear_camera',           
    'downward_camera',       
    'side_camera_left',      
    'side_camera_right',     
    'lidar_sensor',          
    'radar_sensor',          
    'imu_sensor',            
    'gps_module',            
    'barometer',             
]
print(Sensor_array[0])

print(Sensor_array[-1])

Sensor_array.append('thermal_camera')
print(Sensor_array)

Sensor_array.insert(2,'infrared_camera')
print(Sensor_array)

Sensor_array.remove('lidar_sensor')
print(Sensor_array)
# Out:
# front_camera
# barometer
# ['front_camera', 'rear_camera', 'downward_camera', 'side_camera_left', 'side_camera_right', 'lidar_sensor', 'radar_sensor', 'imu_sensor', 'gps_module', 'barometer', 'thermal_camera']
# ['front_camera', 'rear_camera', 'infrared_camera', 'downward_camera', 'side_camera_left', 'side_camera_right', 'lidar_sensor', 'radar_sensor', 'imu_sensor', 'gps_module', 'barometer', 'thermal_camera']
# ['front_camera', 'rear_camera', 'infrared_camera', 'downward_camera', 'side_camera_left', 'side_camera_right', 'radar_sensor', 'imu_sensor', 'gps_module', 'barometer', 'thermal_camera']

# %% [markdown]
# ### Slicing a list
# To derive a segment, you need to specify the index of the first element and where to stop slicing.
#
# In Python, we use a colon(:) as a slicing operator. Slicing follows the following syntax.<br>
# <code> list_name[Index_start:Index_end] </code>

# %%
Sensor_array = [
    'front_camera',          
    'rear_camera',           
    'downward_camera',       
    'side_camera_left',      
    'side_camera_right',     
    'lidar_sensor',          
    'radar_sensor',          
    'imu_sensor',            
    'gps_module',            
    'barometer',             
]
print(Sensor_array[0:3])
print(Sensor_array[:3])
print(Sensor_array[3:])

#######################################################
# exercise 1: list items including index 2 and 4      #
# Hint:                                               #
#      last number in range is not included           #
#######################################################
# Out:
# ['front_camera', 'rear_camera', 'downward_camera']
# ['front_camera', 'rear_camera', 'downward_camera']
# ['side_camera_left', 'side_camera_right', 'lidar_sensor', 'radar_sensor', 'imu_sensor', 'gps_module', 'barometer']

# %% [markdown]
# # Dictionaries
# Dictionaries are used to store data values in key:value pairs.
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#
#     dict = {
#         "key": "value",
#         "string": "Name",
#         "number": 40,
#         "list " : [item1, item2, ....]
#         "dict " : {'key', 'value'}
#     }

# %%
flightSystemDetails = {
    "platform": "fixed_wing_uav",

    "capabilities": {
        "endurance_min": 120,
        "range_km": 150,
        "max_altitude_m": 3000
    },

    "sensors": [
        "front_camera",
        "imu",
        "gps",
        "barometer",
        "airspeed_sensor"
    ],

    "tracking": [
        "MOT",
        "Visual",
        "kalman_filter",
        "deep_sort"
    ],
   "home": {
        "latitude": 19.311143,
        "longitude": 185.849324,
    },
    "status": "operational",

}

print(flightSystemDetails)
# Out:
# {'platform': 'fixed_wing_uav', 'capabilities': {'endurance_min': 120, 'range_km': 150, 'max_altitude_m': 3000}, 'sensors': ['front_camera', 'imu', 'gps', 'barometer', 'airspeed_sensor'], 'tracking': ['MOT', 'Visual', 'kalman_filter', 'deep_sort'], 'home': {'latitude': 19.311143, 'longitude': 185.849324}, 'status': 'operational'}

# %%
#accessing dictionary items
print(flightSystemDetails["platform"])
print(flightSystemDetails.items())
print(flightSystemDetails.keys())
print(flightSystemDetails.values())
# Out:
# fixed_wing_uav
# dict_items([('platform', 'fixed_wing_uav'), ('capabilities', {'endurance_min': 120, 'range_km': 150, 'max_altitude_m': 3000}), ('sensors', ['front_camera', 'imu', 'gps', 'barometer', 'airspeed_sensor']), ('tracking', ['MOT', 'Visual', 'kalman_filter', 'deep_sort']), ('home', {'latitude': 19.311143, 'longitude': 185.849324}), ('status', 'operational')])
# dict_keys(['platform', 'capabilities', 'sensors', 'tracking', 'home', 'status'])
# dict_values(['fixed_wing_uav', {'endurance_min': 120, 'range_km': 150, 'max_altitude_m': 3000}, ['front_camera', 'imu', 'gps', 'barometer', 'airspeed_sensor'], ['MOT', 'Visual', 'kalman_filter', 'deep_sort'], {'latitude': 19.311143, 'longitude': 185.849324}, 'operational'])

# %%
# update dictionary items
flightSystemDetails.update({"status": "grounded"})
print(flightSystemDetails)
#delete item from dictionary
del flightSystemDetails['home']
print(flightSystemDetails)
# Out:
# {'platform': 'fixed_wing_uav', 'capabilities': {'endurance_min': 120, 'range_km': 150, 'max_altitude_m': 3000}, 'sensors': ['front_camera', 'imu', 'gps', 'barometer', 'airspeed_sensor'], 'tracking': ['MOT', 'Visual', 'kalman_filter', 'deep_sort'], 'home': {'latitude': 19.311143, 'longitude': 185.849324}, 'status': 'grounded'}
# {'platform': 'fixed_wing_uav', 'capabilities': {'endurance_min': 120, 'range_km': 150, 'max_altitude_m': 3000}, 'sensors': ['front_camera', 'imu', 'gps', 'barometer', 'airspeed_sensor'], 'tracking': ['MOT', 'Visual', 'kalman_filter', 'deep_sort'], 'status': 'grounded'}

# %%
#iterate over dictionary
for key, item in flightSystemDetails.items():
    print(f'userDetails["{key}"] = {item}')
# Out:
# userDetails["platform"] = fixed_wing_uav
# userDetails["capabilities"] = {'endurance_min': 120, 'range_km': 150, 'max_altitude_m': 3000}
# userDetails["sensors"] = ['front_camera', 'imu', 'gps', 'barometer', 'airspeed_sensor']
# userDetails["tracking"] = ['MOT', 'Visual', 'kalman_filter', 'deep_sort']
# userDetails["status"] = grounded

# %% [markdown]
# ### Loops 🔄
# Python have two major loops <br><br>
#     <code> For Loop </code><br>
#         &emsp; for (place holders ) in (range, list, iterator):<br>
#             &emsp;&emsp;&emsp;do action<br>
#
# <code> While Loop </code><br>
#     &emsp; while condition:<br>
#             &emsp;&emsp;&emsp;do action<br>

# %% [markdown]
# ### for loop

# %%
# range is a python's builtin function which returnes a list of numbers
# in the given range it takes 3 arguments which are as following
# arg1: starting_Point  arg2: end_point   arg_3: Step_size

for x in range(2, 30, 3):
  print(x, end=', ')

#######################################################
# exercise 1: change above given loop to only print   #
# even numbers between 4 and 100                      #
# Hint:                                               #
#      start from 4 and increment wiht 2              #
#######################################################

#######################################################
# exercise 2: uncomment line number 22~25 and rerun   #
# Hint:                                               #
#      zip is used toreshape merge multiple iterators into   #
#      one single iteratr wiht valued mapeed on index #
#######################################################

# fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
# prices  = [1,2,3,4,5]
# for fruit, price in zip(fruits, prices):
#     print(f"{fruit} is sold for {price}")
# Out:
# 2, 5, 8, 11, 14, 17, 20, 23, 26, 29,

# %% [markdown]
# ### while Loop

# %%
number = 1
while int(number) > 0:
    number = input("Enter a +ve number or -ve/0 to end ")
# else:
#     print("so it finally end." )

###################################################
# exercise 1: uncomment line number 4&5 and rerun #
# exercise 2: update loop to also exit for number #
# bigger than 20.                                 #
# Hint use 'and' or break statement               #
###################################################

# %% [markdown]
# ### List Comprehension

# %%
Sensor_array = [
    'front_camera',          
    'rear_camera', 
    'imu_sensor',            
    'gps_module',            
    'barometer',             
]
newlist = []
for x in Sensor_array:
  if "a" in x:
    newlist.append(x)
print(newlist)
# Out:
# ['front_camera', 'rear_camera', 'barometer']

# %%
Sensor_array = [
    'front_camera',          
    'rear_camera', 
    'imu_sensor',            
    'gps_module',            
    'barometer',             
]
newlist = [x for x in Sensor_array if "a" in x]
print(newlist)
# Out:
# ['front_camera', 'rear_camera', 'barometer']

# %% [markdown]
# ## Functions
# A function is a block of code which only runs when it is called.<br>
# You can pass data, known as parameters, into a function.<br>
# A function may and maynot return data as a result.<br>
#
# <b>Syntax</b><br>
#
#     def functionName(parameters .....):
#         do action
#         return data

# %%
def print_n_time(message, count):
    for i in range(count):
        print(message)

def debug_log(level, debug_msg):
    import time # time is an external module will be discussed later
    if level >5:
        print(f"[ DBG ] {debug_msg}")
    else :
        print(f"[ DBG ] [{time.time()}] {debug_msg}")

debug_log(1,"hello")
debug_log(8,"hello")

########################################
# exercise 1: add your own debug level #
# hint:                                #
# add a new elif statemtn              #
########################################
# Out:
# [ DBG ] [1775798015.929161] hello
# [ DBG ] hello

# %%
def line(m, x, c):
    return m*x + c

def predict_next(weights, _input):
    pred = line(weights, _input, 0)
    return _input, pred

_input, prediction = predict_next(12,4)
print(f'Input: {_input} Prediction: {prediction}')

#######################################
# exercise 1: modify predict_next to  #
# take extra argument named as biase  #
# and add it to line function's       #
# input(c)                            #
# hint:                               #
# functio signature should look like  #
# predict_next(weight, _input, biase) #
#######################################
# Out:
# Input: 4 Prediction: 48

# %%
#######################################
# exercise 1: write a function named  #
# relu with following functinality    #
# return 0 if number is -ve or same   #
# number is returned                  #
# hint:                               #
# Use IF-else and return              #
# functio signature                   #
# def relu(input)                     #
#######################################


# def sigmoid(x):
#     z = (1./(1. + np.exp(-x)))
#     return z
