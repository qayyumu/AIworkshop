# %% [markdown]
# <a href="https://colab.research.google.com/github/qayyumu/GradioExp/blob/main/session_02/OpenAI_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OpenAI <table class="tfo-notebook-buttons" align="right" style="margin-top:0px">
#   <td>
#       <a align='left' target="_blank" href="https://www.python.org/doc/"><img src="https://freepnglogo.com/images/all_img/1702059309openai-logo-png.png"  width="150" /></a>
#   </td>
#  </table>

# %%
# %%capture
# !pip install openai 2>/dev/null
# !pip install python-dotenv 2>/dev/null

# %% [markdown]
# #### Import required libraries

# %%
from openai import OpenAI
import os
import openai
import IPython

# %% [markdown]
# #### Setup Environment

# %%
from dotenv import load_dotenv
load_dotenv()
openai.api_key = %env OPENAI_API_KEY
client = OpenAI()


# openai.api_key = os.environ["OPENAI_API_KEY"]
# client = OpenAI()

# ###for colab, add the secret key
# from google.colab import userdata
# client = OpenAI(api_key = userdata.get('OPENAI_API_KEY'))

# %% [markdown]
# ## Text Completion and Generation

# %%
completion = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
    {"role": "system", "content": "You are a AI expert and have multiple successful startups. Running successful companies you help people to grow business in AI technology and solve real world problems"},
    {"role": "user", "content": "Provide an idea on AI for robotics"}
  ]
)

# %%
print(completion.choices[0].message.content)
# Out:
# **AI-Driven Autonomous Inspection Drones for Infrastructure Maintenance**
#
# ### Concept Overview:
# Develop a fleet of autonomous drones equipped with AI-powered vision systems to conduct real-time inspections of critical infrastructure, such as bridges, dams, power lines, and pipelines. These drones will utilize machine learning algorithms to identify structural defects, assess damage, and generate detailed reports to facilitate timely maintenance and ensure safety.
#
# ### Key Features:
#
# 1. **Advanced Machine Learning Algorithms:**
#    - Develop algorithms that can analyze images and video feeds to detect anomalies such as cracks, corrosion, or structural deformities.
#    - Use deep learning techniques to enhance the drones' ability to recognize patterns and differentiate between normal wear and severe damage.
#
# 2. **3D Mapping and Modeling:**
#    - Integrate LiDAR technology to create 3D models of the inspected structures, allowing for detailed visualization of areas that require attention.
#    - Enable historical comparison by storing and analyzing past inspection data.
#
# 3. **Autonomous Navigation:**
#    - Utilize advanced navigation systems that combine GPS, computer vision, and obstacle avoidance to enable drones to navigate complex environments without human intervention.
#    - Allow for pre-planned routes as well as real-time adjustments based on environmental changes.
#
# 4. **Real-Time Data Analytics:**
#    - Implement onboard processing capabilities to analyze data in real-time and provide instant feedback to maintenance teams.
#    - Create a cloud-based platform that aggregates data from multiple inspections, offering predictive analytics and trend analysis.
#
# 5. **Reporting and Maintenance Scheduling:**
#    - Generate automated reports that summarize inspection findings, complete with images, graphs, and recommendations for maintenance.
#    - Integrate with maintenance management systems to schedule repairs based on urgency and available resources.
#
# 6. **User-Friendly Interface:**
#    - Develop a mobile app or web platform for engineers and maintenance teams to remotely monitor drone operations, review inspection data, and manage maintenance schedules.
#
# ### Potential Applications:
# - Inspecting bridges and tunnels for wear and tear, ensuring they meet safety standards.
# - Monitoring oil and gas pipelines for leaks or corrosion.
# - Checking wind turbines for structural integrity and maintenance needs.
# - Assessing the condition of solar panels and other renewable energy installations.
#
# ### Business Model:
# - **Service-Based Model:** Charge clients for inspection services on a per-trip basis or via subscription for regular monitoring.
# - **Data Analytics Subscription:** Offer clients access to the cloud-based analytics platform with insights and predictive maintenance tools.
# - **Partnerships:** Collaborate with infrastructure companies, municipal governments, and utility providers to secure multi-year contracts.
#
# ### Impact:
# This solution not only enhances safety and reliability through timely maintenance but also reduces costs associated with delayed inspections and emergency repairs. Furthermore, it minimizes human risk by using drones to access difficult or hazardous locations.
#
# ### Next Steps:
# - Conduct market research to identify target industries and gather feedback on specific needs.
# - Prototype a drone with basic inspection capabilities and test it in real-world scenarios.
# - Explore partnerships with existing drone manufacturers and machine learning developers to strengthen technological foundations.

# %% [markdown]
# ### tweet generation in urdu

# %%
# Text Generation for Twitter (Urdu)
# tweet_prompt_ur = "تازہ ترین  ڈیٹا کی بنیاد پر سائبر سیکیورٹی خطرات میں حالیہ رجحانات کا تجزیہ کرنے والا ٹویٹ بنائیں۔"
tweet_prompt_ur = "I have written a diffusion model for path planning"

completion_ur = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        # {"role": "system", "content": "آپ سائبر سیکیورٹی رجحانات پر توجہ مرکوز کرنے والے ماہر ہیں۔"},
         {"role": "system", "content": "You are expert in the machine learning and robotics field"},
        {"role": "user", "content": tweet_prompt_ur}
    ]
)

# %%
print("Generated Tweet (Urdu):")
print(completion_ur.choices[0].message.content)
# Out:
# Generated Tweet (Urdu):
# That's great to hear! Diffusion models have gained popularity in various applications, including computer vision and natural language processing, but their application in robotics and path planning is quite innovative. The concept of using diffusion processes for path planning could potentially provide smoother trajectories and improved exploration strategies.
#
# Here are a few points that might help you refine your model or address any challenges:
#
# 1. **Modeling the Environment**: Ensure that your diffusion model accurately represents the environment. This includes obstacles, dynamic elements, and potential goals. You might want to consider how to incorporate different cost functions for different regions.
#
# 2. **Diffusion Process**: In a typical diffusion model, you might use a spatial diffusion process to model how states propagate across the state space. Make sure you define the diffusion coefficient and boundary conditions appropriately for your application.
#
# 3. **Exploration vs. Exploitation**: Diffusion models can be versatile for exploration. You might consider integrating strategies that balance exploration (discovering new paths) and exploitation (following known good paths) to optimize the path planning process.
#
# 4. **Algorithm Complexity**: Analyze the computational efficiency of your model. Diffusion processes can sometimes be computationally expensive. Techniques like parallelization or using approximations may improve performance.
#
# 5. **Robustness Against Uncertainty**: Consider how your model handles uncertainty in sensor data or in the dynamics of the environment. Robust strategies might involve probabilistic planning or incorporating feedback loops.
#
# 6. **Comparison with Traditional Methods**: It might be insightful to compare your diffusion-based method with traditional path planning algorithms (like A*, Dijkstra, RRT, etc.) in terms of efficiency, optimality, and robustness.
#
# 7. **Real-world Testing**: If you haven't done so already, testing in a simulated or real-world environment can provide invaluable insights into the practicality of your model.
#
# 8. **Collaboration**: If you're open to feedback, consider sharing your model or results with others in the field for collaborative improvement. This could lead to enhancements or new perspectives on your approach.
#
# If you have specific questions or areas where you'd like more feedback, feel free to ask!

# %% [markdown]
# ### MultiLingual Twitter text classification

# %%
# Text Classification  on Twitter (English)
tweets_en = [
    "Breaking: New malware attack reported affecting thousands of devices globally.",
    "Just attended an amazing cybersecurity conference. Learned a lot!",
    "Cybersecurity is a crucial aspect of modern technology."
]

examples = [
    ["Breaking: New malware attack reported affecting thousands of devices globally.", "Cybersecurity Threat"],
    ["Just attended an amazing cybersecurity conference. Learned a lot!", "Event"],
    ["Cybersecurity is a crucial aspect of modern technology.", "General Statement"]
]

def classify_tweet(tweet):
    messages = [
        {"role": "system", "content": "You are a helpful assistant who classifies tweets into categories."},
        {"role": "user", "content": f"Classify the following tweet into one of the following categories: Cybersecurity Threat, Event, General Statement.\nTweet: {tweet}"}
    ]

    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-3.5-turbo"
        messages=messages,
        max_tokens=10
    )
    return response.choices[0].message.content

# Classify each tweet
for tweet in tweets_en:
    category = classify_tweet(tweet)
    print(f"Classified Tweet: {tweet}\nCategory: {category}\n")
# Out:
# Classified Tweet: Breaking: New malware attack reported affecting thousands of devices globally.
# Category: Category: Cybersecurity Threat
#
# Classified Tweet: Just attended an amazing cybersecurity conference. Learned a lot!
# Category: Category: Event
#
# Classified Tweet: Cybersecurity is a crucial aspect of modern technology.
# Category: The tweet can be classified as a **General Statement

# %%
# Text Classification on Twitter (Urdu)
tweets_ur = [
    "نئی مالویئر حملے کی خبر: ہزاروں آلات پر اثر انداز ہو رہی ہے۔",
    "بس ایک حیرت انگیز سائبر سیکیورٹی کانفرنس میں شرکت کی۔ بہت کچھ سیکھا!",
    "سائبر سیکیورٹی جدید ٹیکنالوجی کا ایک اہم پہلو ہے۔"
]

def classify_tweet(tweet):
    messages = [
        {"role": "system", "content": f"You are a helpful assistant who classifies tweets into categories."},
        {"role": "user", "content": f"Classify the following tweet into one of the following categories: Cybersecurity Threat, Event, General Statement.\nTweet: {tweet}"}
    ]

    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-3.5-turbo"
        messages=messages,
        max_tokens=10
    )
    return response.choices[0].message.content

# Classify each tweet
for tweet in tweets_ur:
    category = classify_tweet(tweet)
    print(f"Classified Tweet: {tweet}\nCategory: {category}\n")
# Out:
# Classified Tweet: نئی مالویئر حملے کی خبر: ہزاروں آلات پر اثر انداز ہو رہی ہے۔
# Category: The tweet can be classified as **Cybersecurity Threat
#
# Classified Tweet: بس ایک حیرت انگیز سائبر سیکیورٹی کانفرنس میں شرکت کی۔ بہت کچھ سیکھا!
# Category: The tweet can be classified under the category: Event
#
# Classified Tweet: سائبر سیکیورٹی جدید ٹیکنالوجی کا ایک اہم پہلو ہے۔
# Category: The tweet falls under the category: General Statement.

# %%
# Text Classification on Twitter (Pashto)
tweets_pashto = [
    "نوی مالویر برید راپور شو چې په نړیواله کچه په زرګونو وسایلو اغیزه کوي.",
    "یوازې د سایبر امنیتي کنفرانس کې برخه اخیستې وه. ډیر څه زده کړل!",
    "سایبر امنیت د عصري ټیکنالوژۍ یوه مهمه برخه ده."
]
print("Classified Tweet (Pashto):")
for tweet in tweets_ur:
    category = classify_tweet(tweet)
    print(f"Classified Tweet: {tweet}\nCategory: {category}\n")
# Out:
# Classified Tweet (Pashto):
# Classified Tweet: نئی مالویئر حملے کی خبر: ہزاروں آلات پر اثر انداز ہو رہی ہے۔
# Category: The tweet can be classified as **Cybersecurity Threat
#
# Classified Tweet: بس ایک حیرت انگیز سائبر سیکیورٹی کانفرنس میں شرکت کی۔ بہت کچھ سیکھا!
# Category: Category: Event
#
# Classified Tweet: سائبر سیکیورٹی جدید ٹیکنالوجی کا ایک اہم پہلو ہے۔
# Category: The tweet translates to "Cybersecurity is an important

# %%
# Text Generation on Twitter (Hindi)
tweet_prompt_Hindi = "ਤਾਜ਼ਾ  ਡਾਟਾ ਦੇ ਆਧਾਰ ਤੇ ਸਾਈਬਰ ਸੁਰੱਖਿਆ ਖਤਰੇ ਵਿੱਚ ਤਾਜ਼ਾ ਰੁਝਾਨਾਂ ਦਾ ਵਿਸ਼ਲੇਸ਼ਣ ਕਰਨ ਵਾਲੀ ਟਵੀਟ ਬਣਾਓ।"
completion_Hindi = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "ਤੁਸੀਂ ਸਾਈਬਰ ਸੁਰੱਖਿਆ ਰੁਝਾਨਾਂ ਤੇ ਧਿਆਨ ਕੇਂਦਰਿਤ ਕਰਨ ਵਾਲੇ OSINT ਵਿਸ਼ੇਸ਼ਜਨ ਹੋ।"},
        {"role": "user", "content": tweet_prompt_Hindi}
    ]
)

# %%
print("Generated Tweet (Hindi):")
print(completion_Hindi.choices[0].message.content)
# Out:
# Generated Tweet (Hindi):
# 🌐🔍 ਸਾਈਬਰ ਸੁਰੱਖਿਆ ਖਤਰਿਆਂ ਵਿੱਚ ਨਵੇਂ ਰੁਝਾਨ:
#
# 1️⃣ **ਰੈਂਸਮਵੇਰ ਵਿੱਚ ਵਾਧਾ**: ਜਿਥੇ ਵੱਡੇ ਸੰਸਥਾਪਨ ਟారਗਟ ਬਣ ਰਹੇ ਹਨ, ਤਜਰਬਾ ਸਾਂਝਾ ਕਰਨ ਦੀ ਜਰੂਰਤ।
#
# 2️⃣ **ਮਲਟੀ-ਫੈਕਟਰ ਪ੍ਰੱਤੀਪਾਦਨ (MFA)**: ਜ਼ਿਆਦਾ ਸੁਰੱਖਿਆ ਲਈ MFA ਦੀ ਜ਼ੋਰਦਾਰੀ।
#
# 3️⃣ **ਕਲਾਉਡ ਸੁਰੱਖਿਆ**: ਕੁਲ ਦਾਤਾਵਾਹਕਾਂ ਦੀ ਵਧਦੀ ਮੰਗ ਨਾਲ, ਚੁਣੌਤੀਆਂ ਵੀ ਵਧ ਰਹੀਆਂ ਹਨ।
#
# 4️⃣ **ਹੈਕਰ ਫੋਰਮਸ ਦਾ ਉਭਾਰ**: ਕਾਲੇ ਬਜ਼ਾਰਾਂ ਵਿੱਚ ਜਾਣਕਾਰੀ ਦੀ ਆਸਾਨੀ ਨਾਲ ਕਿਰਾਇਆ ਉਪਰੰਤ, ਖਤਰਿਆਂ ਦਾ ਪਸਨਾ।
#
# 🚨 ਚੇਤਾਵਨੀ! ਸੁਰੱਖਿਆ ਵਿਚ ਸੂਚਨਾ ਵੱਡੀ ਪੈਮੀਰ ਹੈ। #CyberSecurity #ThreatTrends #OSINT

# %% [markdown]
# ## Audio Generation  from Text

# %%
response = client.audio.speech.create(
    model="tts-1",
    voice="alloy",
    # input="ہم اپنے ملک سے بہت محبت کرتے ہیں اور اس کے لیے اپنی جان قربان کرنے کے لیے تیار ہیں۔",
    input="你好。你喜欢讲座吗",
)

response.stream_to_file("output.mp3")
# Out:
# /var/folders/jr/58xb1wz12xj9twstx8cwl_rw0000gp/T/ipykernel_61943/2985375731.py:8: DeprecationWarning: Due to a bug, this method doesn't actually stream the response content, `.with_streaming_response.method()` should be used instead
#   response.stream_to_file("output.mp3")

# %%
IPython.display.Audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Image Generation

# %%
if (1):
  response = client.images.generate(
    model="dall-e-3",
    prompt="A Pakistani flag with faisal mosque in the background",
    size="1024x1024",
    quality="standard",
    n=1,
  )

# %%
image_url = response.data[0].url
print(image_url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-rZOR5A4vLgEAZGYa0OLQQdl3/user-ZlUeGIcuiksB704niStKVP8I/img-TafdAS08IkEpsfcB4HALjOW5.png?st=2026-03-23T13%3A33%3A34Z&se=2026-03-23T15%3A33%3A34Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=7252282d-c412-4b10-a746-00f5af2a7888&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-03-23T01%3A34%3A31Z&ske=2026-03-24T01%3A34%3A31Z&sks=b&skv=2026-02-06&sig=EOv8M57GE9BkxH1Z2PzP69xK5kB2BJCPaOpHcQDcrxU%3D

# %%
from IPython.display import Image
Image(url= image_url)
# Out:
# <img src="https://oaidalleapiprodscus.blob.core.windows.net/private/org-rZOR5A4vLgEAZGYa0OLQQdl3/user-ZlUeGIcuiksB704niStKVP8I/img-TafdAS08IkEpsfcB4HALjOW5.png?st=2026-03-23T13%3A33%3A34Z&se=2026-03-23T15%3A33%3A34Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=7252282d-c412-4b10-a746-00f5af2a7888&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-03-23T01%3A34%3A31Z&ske=2026-03-24T01%3A34%3A31Z&sks=b&skv=2026-02-06&sig=EOv8M57GE9BkxH1Z2PzP69xK5kB2BJCPaOpHcQDcrxU%3D"/>
